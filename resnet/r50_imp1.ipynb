# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split, GridSearchCV

from tensorflow.keras.applications import *
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout, GlobalAveragePooling2D
from tensorflow.keras.optimizers import Adam

# %%
#configuring gpu memory usage

gpus = tf.config.experimental.list_physical_devices('GPU')

if gpus:
    try:
        # Set a memory limit for the first GPU (assuming at least one GPU is available)
        tf.config.experimental.set_virtual_device_configuration(
            gpus[0],
            [tf.config.experimental.VirtualDeviceConfiguration(memory_limit=4096)])  # Limit to 4GB
        
        # After setting the configuration, list logical GPUs to verify the configuration
        logical_gpus = tf.config.experimental.list_logical_devices('GPU')
        
        # Print information about the available GPUs and logical GPUs
        print(len(gpus), "Physical GPU(s) available,", len(logical_gpus), "Logical GPU(s) configured.")
        
    except RuntimeError as e:
        # Print any runtime error that occurs during configuration
        print("Error:", e)
else:
    print("No GPU(s) available. TensorFlow cannot use GPU acceleration.")
# Out:
# 1 Physical GPU(s) available, 1 Logical GPU(s) configured.

# %%
# helper function to plot model history
def plot_training_history(history):
    # Plot training & validation loss values
    plt.figure(figsize=(12, 6))
    plt.subplot(1, 2, 1)
    plt.plot(history.history['loss'], label='Train Loss')
    plt.plot(history.history['val_loss'], label='Val Loss')
    plt.title('Model Loss')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.legend()

    # Plot training & validation accuracy values
    plt.subplot(1, 2, 2)
    plt.plot(history.history['accuracy'], label='Train Accuracy')
    plt.plot(history.history['val_accuracy'], label='Val Accuracy')
    plt.title('Model Accuracy')
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy')
    plt.legend()

    plt.tight_layout()
    plt.show()

# %% [markdown]
# ## Reading and preparing data for model training, Using ImageDataGenrator from tensorflow to use image augmentations for training.

# %%
df = pd.read_csv("../balanced_data.csv")
df['cancer'] = df['cancer'].astype(str)

# %%
train_df, val_df = train_test_split(df, test_size=0.2, random_state=101)

IMAGE_SIZE = (256, 256)
BATCH_SIZE = 16
NUM_EPOCHS = 50
LEARNING_RATE = 0.001
INPUT_FOLDER = '../Dataset2'

# %%
#setting up the training and validation datagenerator objects.

train_datagen = ImageDataGenerator(
    rescale=1./255,             
    rotation_range=20,          
    width_shift_range=0.2,      
    height_shift_range=0.2,     
    shear_range=0.2,            
    zoom_range=0.2,             
    horizontal_flip=True       
)

val_datagen = ImageDataGenerator(rescale=1./255)

# %%
train_generator = train_datagen.flow_from_dataframe(
    dataframe=train_df,
    directory=INPUT_FOLDER,                 
    x_col='image_name',                      
    y_col='cancer',                       
    target_size=IMAGE_SIZE,                
    batch_size=16,
    class_mode='binary'                   
)


val_generator = val_datagen.flow_from_dataframe(
    dataframe=val_df,
    directory=INPUT_FOLDER,
    x_col='image_name',
    y_col='cancer',
    target_size=IMAGE_SIZE,
    batch_size=16,
    class_mode='binary'
)
# Out:
# Found 1852 validated image filenames belonging to 2 classes.
# Found 464 validated image filenames belonging to 2 classes.

# %% [markdown]
# ## Model training and evalutation metrics.

# %%
base_model = ResNet50V2(weights='imagenet',input_shape=(256,256,3),include_top=False)

for layer in base_model.layers:
    layer.trainable = False

# %%
model = Sequential()
model.add(base_model)
model.add(GlobalAveragePooling2D())
model.add(Dense(256, activation='relu'))
#model.add(Dropout(0.2)) 
model.add(Dense(1,activation='sigmoid'))

optimizer = Adam(learning_rate=LEARNING_RATE)
model.compile(optimizer=optimizer,loss=['binary_crossentropy'],metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  resnet50v2 (Functional)     (None, 8, 8, 2048)        23564800
#
#  global_average_pooling2d (G  (None, 2048)             0
#  lobalAveragePooling2D)
#
#  dense (Dense)               (None, 256)               524544
#
#  dense_1 (Dense)             (None, 1)                 257
#
# =================================================================
# Total params: 24,089,601
# Trainable params: 524,801
# Non-trainable params: 23,564,800
# _________________________________________________________________

# %%
model_history = model.fit(train_generator,epochs=50,validation_data=val_generator,steps_per_epoch=50)
# Out:
# Epoch 1/50
# 50/50 [==============================] - 12s 146ms/step - loss: 0.8088 - accuracy: 0.5200 - val_loss: 0.7038 - val_accuracy: 0.5216
# Epoch 2/50
# 50/50 [==============================] - 7s 137ms/step - loss: 0.6861 - accuracy: 0.5854 - val_loss: 0.6959 - val_accuracy: 0.5560
# Epoch 3/50
# 50/50 [==============================] - 7s 136ms/step - loss: 0.6839 - accuracy: 0.5738 - val_loss: 0.7208 - val_accuracy: 0.5065
# Epoch 4/50
# 50/50 [==============================] - 7s 138ms/step - loss: 0.6719 - accuracy: 0.5850 - val_loss: 0.6907 - val_accuracy: 0.5582
# Epoch 5/50
# 50/50 [==============================] - 7s 140ms/step - loss: 0.6736 - accuracy: 0.5905 - val_loss: 0.6919 - val_accuracy: 0.5603
# Epoch 6/50
# 50/50 [==============================] - 7s 138ms/step - loss: 0.6839 - accuracy: 0.5462 - val_loss: 0.6857 - val_accuracy: 0.5409
# Epoch 7/50
# 50/50 [==============================] - 7s 136ms/step - loss: 0.6651 - accuracy: 0.6030 - val_loss: 0.6814 - val_accuracy: 0.5776
# Epoch 8/50
# 50/50 [==============================] - 7s 139ms/step - loss: 0.6727 - accuracy: 0.5867 - val_loss: 0.7036 - val_accuracy: 0.5302
# Epoch 9/50
# 50/50 [==============================] - 7s 139ms/step - loss: 0.6554 - accuracy: 0.6025 - val_loss: 0.7570 - val_accuracy: 0.5345
# Epoch 10/50
# 50/50 [==============================] - 7s 143ms/step - loss: 0.6662 - accuracy: 0.6055 - val_loss: 0.6861 - val_accuracy: 0.5453
# Epoch 11/50
# 50/50 [==============================] - 7s 139ms/step - loss: 0.6585 - accuracy: 0.6055 - val_loss: 0.6763 - val_accuracy: 0.5991
# Epoch 12/50
# 50/50 [==============================] - 7s 139ms/step - loss: 0.6665 - accuracy: 0.5992 - val_loss: 0.7051 - val_accuracy: 0.5474
# Epoch 13/50
# 50/50 [==============================] - 7s 139ms/step - loss: 0.6704 - accuracy: 0.5791 - val_loss: 0.6979 - val_accuracy: 0.5409
# Epoch 14/50
# 50/50 [==============================] - 7s 139ms/step - loss: 0.6601 - accuracy: 0.6150 - val_loss: 0.6826 - val_accuracy: 0.5647
# Epoch 15/50
# 50/50 [==============================] - 7s 139ms/step - loss: 0.6529 - accuracy: 0.5950 - val_loss: 0.6824 - val_accuracy: 0.5647
# Epoch 16/50
# 50/50 [==============================] - 7s 140ms/step - loss: 0.6708 - accuracy: 0.5900 - val_loss: 0.6782 - val_accuracy: 0.5754
# Epoch 17/50
# 50/50 [==============================] - 7s 139ms/step - loss: 0.6519 - accuracy: 0.6037 - val_loss: 0.6846 - val_accuracy: 0.5496
# Epoch 18/50
# 50/50 [==============================] - 7s 140ms/step - loss: 0.6553 - accuracy: 0.6100 - val_loss: 0.6918 - val_accuracy: 0.5539
# Epoch 19/50
# 50/50 [==============================] - 7s 141ms/step - loss: 0.6589 - accuracy: 0.5913 - val_loss: 0.6969 - val_accuracy: 0.5496
# Epoch 20/50
# 50/50 [==============================] - 7s 138ms/step - loss: 0.6413 - accuracy: 0.6212 - val_loss: 0.6898 - val_accuracy: 0.5647
# Epoch 21/50
# 50/50 [==============================] - 7s 140ms/step - loss: 0.6477 - accuracy: 0.6407 - val_loss: 0.6854 - val_accuracy: 0.5841
# Epoch 22/50
# 50/50 [==============================] - 7s 143ms/step - loss: 0.6565 - accuracy: 0.5987 - val_loss: 0.6874 - val_accuracy: 0.5733
# Epoch 23/50
# 50/50 [==============================] - 7s 142ms/step - loss: 0.6458 - accuracy: 0.6187 - val_loss: 0.6807 - val_accuracy: 0.5711
# Epoch 24/50
# 50/50 [==============================] - 7s 138ms/step - loss: 0.6428 - accuracy: 0.6187 - val_loss: 0.6988 - val_accuracy: 0.5733
# Epoch 25/50
# 50/50 [==============================] - 7s 138ms/step - loss: 0.6565 - accuracy: 0.5791 - val_loss: 0.7646 - val_accuracy: 0.5151
# Epoch 26/50
# 50/50 [==============================] - 7s 139ms/step - loss: 0.6465 - accuracy: 0.6112 - val_loss: 0.6891 - val_accuracy: 0.5388
# Epoch 27/50
# 50/50 [==============================] - 7s 139ms/step - loss: 0.6542 - accuracy: 0.6125 - val_loss: 0.6834 - val_accuracy: 0.5711
# Epoch 28/50
# 50/50 [==============================] - 7s 140ms/step - loss: 0.6510 - accuracy: 0.6018 - val_loss: 0.6844 - val_accuracy: 0.5733
# Epoch 29/50
# 50/50 [==============================] - 7s 140ms/step - loss: 0.6647 - accuracy: 0.5788 - val_loss: 0.6840 - val_accuracy: 0.5603
# Epoch 30/50
# 50/50 [==============================] - 7s 140ms/step - loss: 0.6605 - accuracy: 0.6162 - val_loss: 0.6747 - val_accuracy: 0.5905
# Epoch 31/50
# 50/50 [==============================] - 7s 139ms/step - loss: 0.6360 - accuracy: 0.6332 - val_loss: 0.6785 - val_accuracy: 0.5690
# Epoch 32/50
# 50/50 [==============================] - 7s 139ms/step - loss: 0.6493 - accuracy: 0.6375 - val_loss: 0.6884 - val_accuracy: 0.5647
# Epoch 33/50
# 50/50 [==============================] - 7s 139ms/step - loss: 0.6413 - accuracy: 0.6313 - val_loss: 0.7119 - val_accuracy: 0.5366
# Epoch 34/50
# 50/50 [==============================] - 7s 138ms/step - loss: 0.6566 - accuracy: 0.6068 - val_loss: 0.6774 - val_accuracy: 0.5711
# Epoch 35/50
# 50/50 [==============================] - 7s 138ms/step - loss: 0.6396 - accuracy: 0.6294 - val_loss: 0.6887 - val_accuracy: 0.5711
# Epoch 36/50
# 50/50 [==============================] - 7s 141ms/step - loss: 0.6399 - accuracy: 0.6219 - val_loss: 0.6832 - val_accuracy: 0.5711
# Epoch 37/50
# 50/50 [==============================] - 7s 141ms/step - loss: 0.6431 - accuracy: 0.6162 - val_loss: 0.6635 - val_accuracy: 0.5905
# Epoch 38/50
# 50/50 [==============================] - 7s 141ms/step - loss: 0.6541 - accuracy: 0.6193 - val_loss: 0.6845 - val_accuracy: 0.5453
# Epoch 39/50
# 50/50 [==============================] - 7s 141ms/step - loss: 0.6409 - accuracy: 0.6150 - val_loss: 0.6852 - val_accuracy: 0.5539
# Epoch 40/50
# 50/50 [==============================] - 7s 139ms/step - loss: 0.6326 - accuracy: 0.6313 - val_loss: 0.6731 - val_accuracy: 0.5711
# Epoch 41/50
# 50/50 [==============================] - 7s 139ms/step - loss: 0.6291 - accuracy: 0.6325 - val_loss: 0.6764 - val_accuracy: 0.5841
# Epoch 42/50
# 50/50 [==============================] - 7s 139ms/step - loss: 0.6368 - accuracy: 0.6325 - val_loss: 0.6891 - val_accuracy: 0.5733
# Epoch 43/50
# 50/50 [==============================] - 7s 138ms/step - loss: 0.6362 - accuracy: 0.6432 - val_loss: 0.6723 - val_accuracy: 0.5776
# Epoch 44/50
# 50/50 [==============================] - 7s 140ms/step - loss: 0.6393 - accuracy: 0.6313 - val_loss: 0.6758 - val_accuracy: 0.5582
# Epoch 45/50
# 50/50 [==============================] - 7s 140ms/step - loss: 0.6275 - accuracy: 0.6445 - val_loss: 0.6688 - val_accuracy: 0.5754
# Epoch 46/50
# 50/50 [==============================] - 7s 140ms/step - loss: 0.6395 - accuracy: 0.6263 - val_loss: 0.6837 - val_accuracy: 0.5776
# Epoch 47/50
# 50/50 [==============================] - 7s 139ms/step - loss: 0.6422 - accuracy: 0.6093 - val_loss: 0.6710 - val_accuracy: 0.5905
# Epoch 48/50
# 50/50 [==============================] - 7s 139ms/step - loss: 0.6215 - accuracy: 0.6275 - val_loss: 0.6866 - val_accuracy: 0.5647
# Epoch 49/50
# 50/50 [==============================] - 7s 139ms/step - loss: 0.6353 - accuracy: 0.6425 - val_loss: 0.6973 - val_accuracy: 0.5647
# Epoch 50/50
# 50/50 [==============================] - 7s 138ms/step - loss: 0.6183 - accuracy: 0.6432 - val_loss: 0.6757 - val_accuracy: 0.5948

# %%
plot_training_history(model_history)

# %%
preds_a = (model.predict(val_generator) > 0.5).astype("int32")
y_true = val_generator.classes
# Out:
# 29/29 [==============================] - 2s 39ms/step

# %%
val_loss, val_accuracy = model.evaluate(val_generator, steps=len(val_generator))
# Out:
# 29/29 [==============================] - 1s 30ms/step - loss: 0.6757 - accuracy: 0.5948

# %%
from sklearn.metrics import confusion_matrix, accuracy_score,classification_report

# %%
class_names = val_generator.class_indices.keys()
report = classification_report(y_true, preds_a, target_names=class_names)

# %%
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.46      0.40      0.43       228
#            1       0.48      0.54      0.51       236
#
#     accuracy                           0.47       464
#    macro avg       0.47      0.47      0.47       464
# weighted avg       0.47      0.47      0.47       464

# %%
print(confusion_matrix(y_true, preds_a))
# Out:
# [[ 92 136]
#  [108 128]]

# %%
model.save("resnet50v2_8020.h5")
