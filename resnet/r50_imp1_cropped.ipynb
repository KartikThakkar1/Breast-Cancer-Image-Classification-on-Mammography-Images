# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split, GridSearchCV

from tensorflow.keras.applications import *
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout, GlobalAveragePooling2D

from tensorflow.keras.optimizers import Adam
import os

# %%
#configuring gpu memory usage

gpus = tf.config.experimental.list_physical_devices('GPU')

if gpus:
    try:
        # Set a memory limit for the first GPU (assuming at least one GPU is available)
        tf.config.experimental.set_virtual_device_configuration(
            gpus[0],
            [tf.config.experimental.VirtualDeviceConfiguration(memory_limit=4096)])  # Limit to 4GB
        
        # After setting the configuration, list logical GPUs to verify the configuration
        logical_gpus = tf.config.experimental.list_logical_devices('GPU')
        
        # Print information about the available GPUs and logical GPUs
        print(len(gpus), "Physical GPU(s) available,", len(logical_gpus), "Logical GPU(s) configured.")
        
    except RuntimeError as e:
        # Print any runtime error that occurs during configuration
        print("Error:", e)
else:
    print("No GPU(s) available. TensorFlow cannot use GPU acceleration.")
# Out:
# 1 Physical GPU(s) available, 1 Logical GPU(s) configured.

# %%
# helper function for plotting model history
def plot_training_history(history):
    
    plt.figure(figsize=(12, 6))
    plt.subplot(1, 2, 1)
    plt.plot(history.history['loss'], label='Train Loss')
    plt.plot(history.history['val_loss'], label='Val Loss')
    plt.title('Model Loss')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.legend()

    
    plt.subplot(1, 2, 2)
    plt.plot(history.history['accuracy'], label='Train Accuracy')
    plt.plot(history.history['val_accuracy'], label='Val Accuracy')
    plt.title('Model Accuracy')
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy')
    plt.legend()

    plt.tight_layout()
    plt.show()

# %% [markdown]
# ## Reading and preparing data for model training, Using ImageDataGenrator from tensorflow to use image augmentations for training.

# %%
df = pd.read_csv("../balanced_data.csv")
df['cancer'] = df['cancer'].astype(str)

# %%
cropped_image_names = []
for im in os.listdir('../CroppedDataset2'):
    cropped_image_names.append(im)

# %%
df['cropped_image_path'] = cropped_image_names

# %%
train_df, val_df = train_test_split(df, test_size=0.2, random_state=101)

IMAGE_SIZE = (256, 256)
BATCH_SIZE = 16
NUM_EPOCHS = 50
LEARNING_RATE = 0.001
INPUT_FOLDER = '../CroppedDataset2'

# %%
#setting up the training and validation datagenerator objects.

train_datagen = ImageDataGenerator(
    rescale=1./255,             
    rotation_range=20,          
    width_shift_range=0.2,      
    height_shift_range=0.2,     
    shear_range=0.2,            
    zoom_range=0.2,             
    horizontal_flip=True       
)

val_datagen = ImageDataGenerator(rescale=1./255)

# %%
train_generator = train_datagen.flow_from_dataframe(
    dataframe=train_df,
    directory=INPUT_FOLDER,                 
    x_col='cropped_image_path',                      
    y_col='cancer',                       
    target_size=IMAGE_SIZE,                
    batch_size=16,
    class_mode='binary'                   
)


val_generator = val_datagen.flow_from_dataframe(
    dataframe=val_df,
    directory=INPUT_FOLDER,
    x_col='cropped_image_path',
    y_col='cancer',
    target_size=IMAGE_SIZE,
    batch_size=16,
    class_mode='binary'
)
# Out:
# Found 1852 validated image filenames belonging to 2 classes.
# Found 464 validated image filenames belonging to 2 classes.

# %% [markdown]
# ## Model training and evalutation metrics.

# %%
base_model = ResNet50V2(weights='imagenet',input_shape=(256,256,3),include_top=False)

for layer in base_model.layers:
    layer.trainable = False

# %%
model = Sequential()
model.add(base_model)
model.add(GlobalAveragePooling2D())
model.add(Dense(256, activation='relu'))
#model.add(Dropout(0.2)) 
model.add(Dense(1,activation='sigmoid'))

optimizer = Adam(learning_rate=LEARNING_RATE)
model.compile(optimizer=optimizer,loss=['binary_crossentropy'],metrics=['accuracy'])

# %%
model_history = model.fit(train_generator,epochs=50,validation_data=val_generator,steps_per_epoch=50)
# Out:
# Epoch 1/50
# 50/50 [==============================] - 16s 231ms/step - loss: 0.9195 - accuracy: 0.5088 - val_loss: 0.8155 - val_accuracy: 0.4914
# Epoch 2/50
# 50/50 [==============================] - 9s 176ms/step - loss: 0.7187 - accuracy: 0.5239 - val_loss: 0.7132 - val_accuracy: 0.5000
# Epoch 3/50
# 50/50 [==============================] - 8s 164ms/step - loss: 0.7115 - accuracy: 0.4800 - val_loss: 0.7153 - val_accuracy: 0.5022
# Epoch 4/50
# 50/50 [==============================] - 8s 154ms/step - loss: 0.7057 - accuracy: 0.5239 - val_loss: 0.7242 - val_accuracy: 0.5151
# Epoch 5/50
# 50/50 [==============================] - 7s 148ms/step - loss: 0.6972 - accuracy: 0.5100 - val_loss: 0.7073 - val_accuracy: 0.4720
# Epoch 6/50
# 50/50 [==============================] - 7s 148ms/step - loss: 0.6960 - accuracy: 0.5213 - val_loss: 0.7114 - val_accuracy: 0.5129
# Epoch 7/50
# 50/50 [==============================] - 7s 148ms/step - loss: 0.6976 - accuracy: 0.5151 - val_loss: 0.7040 - val_accuracy: 0.5151
# Epoch 8/50
# 50/50 [==============================] - 7s 143ms/step - loss: 0.6866 - accuracy: 0.5300 - val_loss: 0.7083 - val_accuracy: 0.4935
# Epoch 9/50
# 50/50 [==============================] - 7s 144ms/step - loss: 0.6970 - accuracy: 0.5075 - val_loss: 0.7023 - val_accuracy: 0.5086
# Epoch 10/50
# 50/50 [==============================] - 7s 143ms/step - loss: 0.6899 - accuracy: 0.5375 - val_loss: 0.7162 - val_accuracy: 0.4871
# Epoch 11/50
# 50/50 [==============================] - 7s 142ms/step - loss: 0.6905 - accuracy: 0.5314 - val_loss: 0.7070 - val_accuracy: 0.4741
# Epoch 12/50
# 50/50 [==============================] - 7s 148ms/step - loss: 0.6843 - accuracy: 0.5590 - val_loss: 0.7153 - val_accuracy: 0.4849
# Epoch 13/50
# 50/50 [==============================] - 8s 151ms/step - loss: 0.6906 - accuracy: 0.5025 - val_loss: 0.7088 - val_accuracy: 0.5022
# Epoch 14/50
# 50/50 [==============================] - 8s 151ms/step - loss: 0.6913 - accuracy: 0.5312 - val_loss: 0.7120 - val_accuracy: 0.4849
# Epoch 15/50
# 50/50 [==============================] - 7s 143ms/step - loss: 0.6857 - accuracy: 0.5176 - val_loss: 0.7233 - val_accuracy: 0.4871
# Epoch 16/50
# 50/50 [==============================] - 7s 143ms/step - loss: 0.6787 - accuracy: 0.5462 - val_loss: 0.7512 - val_accuracy: 0.4806
# Epoch 17/50
# 50/50 [==============================] - 7s 145ms/step - loss: 0.6975 - accuracy: 0.5540 - val_loss: 0.7244 - val_accuracy: 0.4763
# Epoch 18/50
# 50/50 [==============================] - 7s 145ms/step - loss: 0.6862 - accuracy: 0.5213 - val_loss: 0.7204 - val_accuracy: 0.4806
# Epoch 19/50
# 50/50 [==============================] - 7s 146ms/step - loss: 0.6849 - accuracy: 0.5675 - val_loss: 0.7234 - val_accuracy: 0.4957
# Epoch 20/50
# 50/50 [==============================] - 7s 149ms/step - loss: 0.6879 - accuracy: 0.5275 - val_loss: 0.7114 - val_accuracy: 0.4784
# Epoch 21/50
# 50/50 [==============================] - 7s 145ms/step - loss: 0.6747 - accuracy: 0.5600 - val_loss: 0.7270 - val_accuracy: 0.4849
# Epoch 22/50
# 50/50 [==============================] - 7s 145ms/step - loss: 0.6803 - accuracy: 0.5525 - val_loss: 0.7223 - val_accuracy: 0.4892
# Epoch 23/50
# 50/50 [==============================] - 7s 144ms/step - loss: 0.6935 - accuracy: 0.5239 - val_loss: 0.7189 - val_accuracy: 0.4828
# Epoch 24/50
# 50/50 [==============================] - 7s 144ms/step - loss: 0.6853 - accuracy: 0.5339 - val_loss: 0.7099 - val_accuracy: 0.5129
# Epoch 25/50
# 50/50 [==============================] - 7s 145ms/step - loss: 0.6758 - accuracy: 0.5612 - val_loss: 0.7326 - val_accuracy: 0.4806
# Epoch 26/50
# 50/50 [==============================] - 7s 147ms/step - loss: 0.6933 - accuracy: 0.5300 - val_loss: 0.7178 - val_accuracy: 0.4806
# Epoch 27/50
# 50/50 [==============================] - 7s 146ms/step - loss: 0.6780 - accuracy: 0.5550 - val_loss: 0.7358 - val_accuracy: 0.4698
# Epoch 28/50
# 50/50 [==============================] - 7s 147ms/step - loss: 0.6921 - accuracy: 0.5113 - val_loss: 0.7135 - val_accuracy: 0.4720
# Epoch 29/50
# 50/50 [==============================] - 7s 147ms/step - loss: 0.6726 - accuracy: 0.5729 - val_loss: 0.7516 - val_accuracy: 0.4849
# Epoch 30/50
# 50/50 [==============================] - 7s 147ms/step - loss: 0.6854 - accuracy: 0.5412 - val_loss: 0.7277 - val_accuracy: 0.4483
# Epoch 31/50
# 50/50 [==============================] - 7s 145ms/step - loss: 0.6765 - accuracy: 0.5704 - val_loss: 0.7265 - val_accuracy: 0.4871
# Epoch 32/50
# 50/50 [==============================] - 7s 147ms/step - loss: 0.6800 - accuracy: 0.5725 - val_loss: 0.7222 - val_accuracy: 0.4828
# Epoch 33/50
# 50/50 [==============================] - 7s 145ms/step - loss: 0.6747 - accuracy: 0.5650 - val_loss: 0.7227 - val_accuracy: 0.4871
# Epoch 34/50
# 50/50 [==============================] - 7s 145ms/step - loss: 0.6792 - accuracy: 0.5875 - val_loss: 0.7251 - val_accuracy: 0.4698
# Epoch 35/50
# 50/50 [==============================] - 7s 145ms/step - loss: 0.6808 - accuracy: 0.5612 - val_loss: 0.7257 - val_accuracy: 0.4698
# Epoch 36/50
# 50/50 [==============================] - 7s 145ms/step - loss: 0.6791 - accuracy: 0.5500 - val_loss: 0.7345 - val_accuracy: 0.4741
# Epoch 37/50
# 50/50 [==============================] - 7s 145ms/step - loss: 0.6828 - accuracy: 0.5540 - val_loss: 0.7267 - val_accuracy: 0.4828
# Epoch 38/50
# 50/50 [==============================] - 7s 144ms/step - loss: 0.6804 - accuracy: 0.5663 - val_loss: 0.7163 - val_accuracy: 0.4978
# Epoch 39/50
# 50/50 [==============================] - 7s 144ms/step - loss: 0.6714 - accuracy: 0.5688 - val_loss: 0.7289 - val_accuracy: 0.4741
# Epoch 40/50
# 50/50 [==============================] - 7s 143ms/step - loss: 0.6796 - accuracy: 0.5603 - val_loss: 0.7229 - val_accuracy: 0.4935
# Epoch 41/50
# 50/50 [==============================] - 7s 145ms/step - loss: 0.6777 - accuracy: 0.5766 - val_loss: 0.7255 - val_accuracy: 0.5000
# Epoch 42/50
# 50/50 [==============================] - 7s 145ms/step - loss: 0.6892 - accuracy: 0.5450 - val_loss: 0.7379 - val_accuracy: 0.4698
# Epoch 43/50
# 50/50 [==============================] - 7s 145ms/step - loss: 0.6773 - accuracy: 0.5850 - val_loss: 0.7315 - val_accuracy: 0.4871
# Epoch 44/50
# 50/50 [==============================] - 7s 145ms/step - loss: 0.6672 - accuracy: 0.5704 - val_loss: 0.7237 - val_accuracy: 0.5172
# Epoch 45/50
# 50/50 [==============================] - 7s 145ms/step - loss: 0.6763 - accuracy: 0.5650 - val_loss: 0.7463 - val_accuracy: 0.4978
# Epoch 46/50
# 50/50 [==============================] - 7s 146ms/step - loss: 0.6761 - accuracy: 0.5850 - val_loss: 0.7213 - val_accuracy: 0.5172
# Epoch 47/50
# 50/50 [==============================] - 7s 145ms/step - loss: 0.6723 - accuracy: 0.5900 - val_loss: 0.7527 - val_accuracy: 0.4612
# Epoch 48/50
# 50/50 [==============================] - 7s 144ms/step - loss: 0.6757 - accuracy: 0.5766 - val_loss: 0.7111 - val_accuracy: 0.4935
# Epoch 49/50
# 50/50 [==============================] - 7s 145ms/step - loss: 0.6716 - accuracy: 0.5612 - val_loss: 0.7397 - val_accuracy: 0.4828
# Epoch 50/50
# 50/50 [==============================] - 7s 145ms/step - loss: 0.6649 - accuracy: 0.5612 - val_loss: 0.7303 - val_accuracy: 0.4914

# %%
plot_training_history(model_history)

# %%
preds_a = (model.predict(val_generator) > 0.5).astype("int32")
y_true = val_generator.classes
# Out:
# 29/29 [==============================] - 2s 44ms/step

# %%
val_loss, val_accuracy = model.evaluate(val_generator, steps=len(val_generator))
# Out:
# 29/29 [==============================] - 1s 32ms/step - loss: 0.7303 - accuracy: 0.4914

# %%
from sklearn.metrics import confusion_matrix, accuracy_score,classification_report

# %%
class_names = val_generator.class_indices.keys()
report = classification_report(y_true, preds_a, target_names=class_names)

# %%
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.47      0.63      0.54       228
#            1       0.46      0.31      0.37       236
#
#     accuracy                           0.47       464
#    macro avg       0.46      0.47      0.45       464
# weighted avg       0.46      0.47      0.45       464
