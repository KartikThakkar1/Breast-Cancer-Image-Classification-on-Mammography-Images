# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split

from tensorflow.keras.applications import *
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout, GlobalAveragePooling2D

from tensorflow.keras.optimizers import Adam

import os
from sklearn.metrics import confusion_matrix, accuracy_score,classification_report

# %%
#configuring gpu memory usage

gpus = tf.config.experimental.list_physical_devices('GPU')

if gpus:
    try:
        # Set a memory limit for the first GPU (assuming at least one GPU is available)
        tf.config.experimental.set_virtual_device_configuration(
            gpus[0],
            [tf.config.experimental.VirtualDeviceConfiguration(memory_limit=4096)])  # Limit to 4GB
        
        # After setting the configuration, list logical GPUs to verify the configuration
        logical_gpus = tf.config.experimental.list_logical_devices('GPU')
        
        # Print information about the available GPUs and logical GPUs
        print(len(gpus), "Physical GPU(s) available,", len(logical_gpus), "Logical GPU(s) configured.")
        
    except RuntimeError as e:
        # Print any runtime error that occurs during configuration
        print("Error:", e)
else:
    print("No GPU(s) available. TensorFlow cannot use GPU acceleration.")
# Out:
# 1 Physical GPU(s) available, 1 Logical GPU(s) configured.

# %%
# helper function to plot model history
def plot_training_history(history):
    # Plot training & validation loss values
    plt.figure(figsize=(12, 6))
    plt.subplot(1, 2, 1)
    plt.plot(history.history['loss'], label='Train Loss')
    plt.plot(history.history['val_loss'], label='Val Loss')
    plt.title('Model Loss')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.legend()

    # Plot training & validation accuracy values
    plt.subplot(1, 2, 2)
    plt.plot(history.history['accuracy'], label='Train Accuracy')
    plt.plot(history.history['val_accuracy'], label='Val Accuracy')
    plt.title('Model Accuracy')
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy')
    plt.legend()

    plt.tight_layout()
    plt.show()

# %% [markdown]
# ## Reading and preparing data for model training, Using ImageDataGenrator from tensorflow to use image augmentations for training.

# %%
df = pd.read_csv("../balanced_data.csv")
df['cancer'] = df['cancer'].astype(str)

# %%
cropped_image_names = []
for im in os.listdir('../CroppedDataset2'):
    cropped_image_names.append(im)

# %%
df['cropped_image_path'] = cropped_image_names

# %%
train_df, val_df = train_test_split(df, test_size=0.08, random_state=101)

IMAGE_SIZE = (256, 256)
BATCH_SIZE = 16
NUM_EPOCHS = 50
LEARNING_RATE = 0.001
INPUT_FOLDER = '../CroppedDataset2'

# %%
#setting up the training and validation datagenerator objects.

train_datagen = ImageDataGenerator(
    rescale=1./255,             
    rotation_range=20,          
    width_shift_range=0.2,      
    height_shift_range=0.2,     
    shear_range=0.2,            
    zoom_range=0.2,             
    horizontal_flip=True       
)

val_datagen = ImageDataGenerator(rescale=1./255)

# %%
train_generator = train_datagen.flow_from_dataframe(
    dataframe=train_df,
    directory=INPUT_FOLDER,                 
    x_col='cropped_image_path',                      
    y_col='cancer',                       
    target_size=IMAGE_SIZE,                
    batch_size=16,
    class_mode='binary'                   
)


val_generator = val_datagen.flow_from_dataframe(
    dataframe=val_df,
    directory=INPUT_FOLDER,
    x_col='cropped_image_path',
    y_col='cancer',
    target_size=IMAGE_SIZE,
    batch_size=16,
    class_mode='binary'
)
# Out:
# Found 2130 validated image filenames belonging to 2 classes.
# Found 186 validated image filenames belonging to 2 classes.

# %% [markdown]
# ## Model training and evalutation metrics.

# %%
base_model = VGG16(weights='imagenet',input_shape=(256,256,3),include_top=False)

for layer in base_model.layers:
    layer.trainable = False

# %%
model = Sequential()
model.add(base_model)
model.add(GlobalAveragePooling2D())
model.add(Dense(256, activation='relu'))
model.add(Dense(1,activation='sigmoid'))

optimizer = Adam(learning_rate=LEARNING_RATE)
model.compile(optimizer=optimizer,loss=['binary_crossentropy'],metrics=['accuracy'])

# %%
model_history = model.fit(train_generator,epochs=50,validation_data=val_generator,steps_per_epoch=50)
# Out:
# Epoch 1/50
# 50/50 [==============================] -
# Epoch 20/50
# 50/50 [==============================] - 7s 142ms/step - loss: 0.6968 - accuracy: 0.5412 - val_loss: 0.6976 - val_accuracy: 0.4946
# Epoch 21/50
# 50/50 [==============================] - 7s 141ms/step - loss: 0.6944 - accuracy: 0.5050 - val_loss: 0.6964 - val_accuracy: 0.4839
# Epoch 22/50
# 50/50 [==============================] - 7s 142ms/step - loss: 0.6945 - accuracy: 0.5113 - val_loss: 0.6926 - val_accuracy: 0.5215
# Epoch 23/50
# 50/50 [==============================] - 7s 141ms/step - loss: 0.6907 - accuracy: 0.5204 - val_loss: 0.6917 - val_accuracy: 0.5000
# Epoch 24/50
# 50/50 [==============================] - 7s 142ms/step - loss: 0.6926 - accuracy: 0.5200 - val_loss: 0.6892 - val_accuracy: 0.5484
# Epoch 25/50
# 50/50 [==============================] - 7s 144ms/step - loss: 0.6973 - accuracy: 0.5400 - val_loss: 0.6924 - val_accuracy: 0.5161
# Epoch 26/50
# 50/50 [==============================] - 7s 144ms/step - loss: 0.6925 - accuracy: 0.5312 - val_loss: 0.6941 - val_accuracy: 0.4946
# Epoch 27/50
# 50/50 [==============================] - 8s 157ms/step - loss: 0.6928 - accuracy: 0.5242 - val_loss: 0.7202 - val_accuracy: 0.4946
# Epoch 28/50
# 50/50 [==============================] - 10s 205ms/step - loss: 0.6992 - accuracy: 0.5038 - val_loss: 0.7025 - val_accuracy: 0.4946
# Epoch 29/50
# 50/50 [==============================] - 15s 297ms/step - loss: 0.6912 - accuracy: 0.5325 - val_loss: 0.6980 - val_accuracy: 0.4624
# Epoch 30/50
# 50/50 [==============================] - 10s 198ms/step - loss: 0.6903 - accuracy: 0.5188 - val_loss: 0.7043 - val_accuracy: 0.4892
# Epoch 31/50
# 50/50 [==============================] - 7s 143ms/step - loss: 0.6996 - accuracy: 0.5229 - val_loss: 0.7033 - val_accuracy: 0.4946
# Epoch 32/50
# 50/50 [==============================] - 7s 147ms/step - loss: 0.6895 - accuracy: 0.5293 - val_loss: 0.7300 - val_accuracy: 0.4946
# Epoch 33/50
# 50/50 [==============================] - 7s 149ms/step - loss: 0.7008 - accuracy: 0.5102 - val_loss: 0.6945 - val_accuracy: 0.4892
# Epoch 34/50
# 50/50 [==============================] - 7s 143ms/step - loss: 0.6938 - accuracy: 0.5013 - val_loss: 0.6961 - val_accuracy: 0.4677
# Epoch 35/50
# 50/50 [==============================] - 7s 143ms/step - loss: 0.6928 - accuracy: 0.5100 - val_loss: 0.6974 - val_accuracy: 0.4946
# Epoch 36/50
# 50/50 [==============================] - 7s 141ms/step - loss: 0.6928 - accuracy: 0.5191 - val_loss: 0.6974 - val_accuracy: 0.4839
# Epoch 37/50
# 50/50 [==============================] - 7s 146ms/step - loss: 0.6916 - accuracy: 0.5200 - val_loss: 0.6957 - val_accuracy: 0.4731
# Epoch 38/50
# 50/50 [==============================] - 7s 143ms/step - loss: 0.6930 - accuracy: 0.5025 - val_loss: 0.6971 - val_accuracy: 0.5323
# Epoch 39/50
# 50/50 [==============================] - 7s 145ms/step - loss: 0.6928 - accuracy: 0.5113 - val_loss: 0.7019 - val_accuracy: 0.4946
# Epoch 40/50
# 50/50 [==============================] - 7s 148ms/step - loss: 0.6919 - accuracy: 0.5229 - val_loss: 0.7012 - val_accuracy: 0.4946
# Epoch 41/50
# 50/50 [==============================] - 7s 144ms/step - loss: 0.6938 - accuracy: 0.5138 - val_loss: 0.6960 - val_accuracy: 0.5269
# Epoch 42/50
# 50/50 [==============================] - 12s 235ms/step - loss: 0.6928 - accuracy: 0.5213 - val_loss: 0.6968 - val_accuracy: 0.5215
# Epoch 43/50
# 50/50 [==============================] - 9s 186ms/step - loss: 0.6912 - accuracy: 0.5312 - val_loss: 0.6974 - val_accuracy: 0.4946
# Epoch 44/50
# 50/50 [==============================] - 16s 306ms/step - loss: 0.6918 - accuracy: 0.5350 - val_loss: 0.6983 - val_accuracy: 0.4892
# Epoch 45/50
# 50/50 [==============================] - 13s 252ms/step - loss: 0.6953 - accuracy: 0.4875 - val_loss: 0.6945 - val_accuracy: 0.5054
# Epoch 46/50
# 50/50 [==============================] - 7s 139ms/step - loss: 0.6932 - accuracy: 0.5242 - val_loss: 0.6943 - val_accuracy: 0.4677
# Epoch 47/50
# 50/50 [==============================] - 9s 181ms/step - loss: 0.6907 - accuracy: 0.5163 - val_loss: 0.7017 - val_accuracy: 0.5054
# Epoch 48/50
# 50/50 [==============================] - 9s 174ms/step - loss: 0.6942 - accuracy: 0.5216 - val_loss: 0.6950 - val_accuracy: 0.5323
# Epoch 49/50
# 50/50 [==============================] - 7s 142ms/step - loss: 0.6933 - accuracy: 0.5113 - val_loss: 0.6944 - val_accuracy: 0.5376
# Epoch 50/50
# 50/50 [==============================] - 7s 145ms/step - loss: 0.6922 - accuracy: 0.5229 - val_loss: 0.6955 - val_accuracy: 0.5269

# %%
plot_training_history(model_history)

# %%
preds_a = (model.predict(val_generator) > 0.5).astype("int32")
y_true = val_generator.classes
# Out:
# 12/12 [==============================] - 1s 81ms/step

# %%
val_loss, val_accuracy = model.evaluate(val_generator, steps=len(val_generator))
# Out:
# 12/12 [==============================] - 1s 57ms/step - loss: 0.6955 - accuracy: 0.5269

# %%
class_names = val_generator.class_indices.keys()
report = classification_report(y_true, preds_a, target_names=class_names)

# %%
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.40      0.18      0.25        94
#            1       0.47      0.73      0.57        92
#
#     accuracy                           0.45       186
#    macro avg       0.44      0.45      0.41       186
# weighted avg       0.43      0.45      0.41       186
